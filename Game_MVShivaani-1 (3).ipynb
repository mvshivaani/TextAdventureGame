# %%
"""@author:mvshivaani"""
"""Subimitted on 18 Oct 2019 to Prof. Chase @ Hult"""

"""
Docstring:
    A) Introduction: The game is about auction of delinquent storage units in the Golden State.
    Bidder is given just once chance to bid, if he has the highest bid, he owns the locker.
    Every locker has 10 (blind)items, successful bidder will choose 6 items, remaining 4 will go to auction house as fee.
    Out of 6, one is a 'supposed collectible' that needs to be appraised. 
    If bidder's total payoff is positive, the aprraiser asks him to accompamy him to Vegas to bet on roulette.
    Are you curious to know:
    Does the bidder get the locker?
    Does his gamble payoff?
    Does he get to Vegas?
    Does he get to own money or money owns him???
    B) Known errors and bugs: None
"""

from sys import exit
import random
import time
import colorama
from colorama import Fore
import emoji

def game_start():
    
    #Introduction to game screen and calls welcome message
    
    print(Fore.GREEN+"""\t\t          
 __  __                           ___                       _____ _     _       _____                   
|  \/  | ___  _ __   ___ _   _   / _ \__      ___ __  ___  |_   _| |__ (_)___  |_   _|____      ___ __  
| |\/| |/ _ \| '_ \ / _ \ | | | | | | \ \ /\ / / '_ \/ __|   | | | '_ \| / __|   | |/ _ \ \ /\ / / '_ \ 
| |  | | (_) | | | |  __/ |_| | | |_| |\ V  V /| | | \__ \   | | | | | | \__ \   | | (_) \ V  V /| | | |
|_|  |_|\___/|_| |_|\___|\__, |  \___/  \_/\_/ |_| |_|___/   |_| |_| |_|_|___/   |_|\___/ \_/\_/ |_| |_|
                         |___/                                                                              
      """)
    print_welcome_message()
    round_1()
    
    
def fail():
    
    # Called when the player loses a round or chooses to exit
    # The function prints exit message and excutes exit command
    
    print(Fore.RED+f"\n\n{bidder_name}, Sorry! You lost\n\n")
    replay=input("\n\nWould you like to play again?? Yes or No??\n\n")
    if replay.casefold() == proceed.casefold():
        round_1()
    else:
        print(f"\t\tThanks for playing {bidder_name}!", Fore.RED+"""\t\t             
  _____          __  __ ______    ______      ________ _____  
 / ____|   /\   |  \/  |  ____|  / __ \ \    / /  ____|  __ \ 
| |  __   /  \  | \  / | |__    | |  | \ \  / /| |__  | |__) |
| | |_ | / /\ \ | |\/| |  __|   | |  | |\ \/ / |  __| |  _  / 
| |__| |/ ____ \| |  | | |____  | |__| | \  /  | |____| | \ \ 
 \_____/_/    \_\_|  |_|______|  \____/   \/   |______|_|  \_\    
                     
              """)
        print(emoji.emojize(":pensive_face:")*30)
        exit(0)

def disqualified():
    
    # Called when the player violates the rules of the game
    # The function prints disqualification message and excutes exit command
    
    print(Fore.RED+f"\n\n{bidder_name}, You aren't following the rules!. You are disqualified!\n\n")
    replay=input("\n\nWould you like to play again?? Yes or No??\n\n")
    if replay.casefold() == proceed.casefold():
        round_1()
    else:
        print(f"\n\nThanks for playing {bidder_name}!", Fore.RED+"""             
  _____          __  __ ______    ______      ________ _____  
 / ____|   /\   |  \/  |  ____|  / __ \ \    / /  ____|  __ \ 
| |  __   /  \  | \  / | |__    | |  | \ \  / /| |__  | |__) |
| | |_ | / /\ \ | |\/| |  __|   | |  | |\ \/ / |  __| |  _  / 
| |__| |/ ____ \| |  | | |____  | |__| | \  /  | |____| | \ \ 
 \_____/_/    \_\_|  |_|______|  \____/   \/   |______|_|  \_\    
                     
              \n\n""")
        print(emoji.emojize(":face_with_rolling_eyes:")*30)
        exit(0)

def conditional_win():
    # If player loses in round 3 but still have money left from winning the locker
    if bid_casino < profit_loss:
        print(Fore.GREEN+f" {bidder_name}, though you lost the bet on roulette table, you are still going home with {profit_loss - bid_casino} dollars.\n\n\t\t Surprised???\n\nIt is just the difference between your locker's profit and casino bet.\n\n\t\tGood Job!!")
        replay=input("\n\nWould you like to play again?? Yes or No??\n\n")
        if replay.casefold() == proceed.casefold():
            round_1()
    
        else:
            print(f"\n\nThanks for playing {bidder_name}!", Fore.GREEN+"""             
  _____          __  __ ______    ______      ________ _____  
 / ____|   /\   |  \/  |  ____|  / __ \ \    / /  ____|  __ \ 
| |  __   /  \  | \  / | |__    | |  | \ \  / /| |__  | |__) |
| | |_ | / /\ \ | |\/| |  __|   | |  | |\ \/ / |  __| |  _  / 
| |__| |/ ____ \| |  | | |____  | |__| | \  /  | |____| | \ \ 
 \_____/_/    \_\_|  |_|______|  \____/   \/   |______|_|  \_\    
                     
              \n\n""")
            print(emoji.emojize(":smiling_face:")*30)
            exit(0)
        
    else:
        fail()
    
        
def end_message():
    
    # Called when the player wins the game
    # Computes and prints the total winnings
    
    print(Fore.GREEN+f"\n\nYou know {bidder_name}, you finally earned {profit_loss + casino_payoff}.\n\n\
Come back for more winnings!")
    
    replay=input("\n\nWould you like to play again?? Yes or No??\n\n")
    
    if replay.casefold() == proceed.casefold():
        round_1()
    
    else:
        print(f"\n\nThanks for playing {bidder_name}!", Fore.GREEN+"""             
  _____          __  __ ______    ______      ________ _____  
 / ____|   /\   |  \/  |  ____|  / __ \ \    / /  ____|  __ \ 
| |  __   /  \  | \  / | |__    | |  | \ \  / /| |__  | |__) |
| | |_ | / /\ \ | |\/| |  __|   | |  | |\ \/ / |  __| |  _  / 
| |__| |/ ____ \| |  | | |____  | |__| | \  /  | |____| | \ \ 
 \_____/_/    \_\_|  |_|______|  \____/   \/   |______|_|  \_\    
                     
              \n\n""")
        print(emoji.emojize(":star-struck:")*30)
        exit(0)
    
def print_welcome_message():
    
    # Welcomes the user and navigates to round_1
    
    global bidder_name
    
    print(Fore.MAGENTA+"""When storage units are abandoned in the Golden State, the treasures within, go up for auction.""")
    
    time.sleep(2)
    

    print(Fore.BLUE+"\n\nGood day! Ladies and Gentlemen!\n\nI am your host DON!!!\n\n")
    time.sleep(1)
    
    print(Fore.BLUE+"Welcome to auction here today!\n\n")
    time.sleep(1)
    
    print(Fore.BLUE+"We have some delinquent accounts here.\n\n")
    time.sleep(1)
    
    print(Fore.BLUE+"What happens here is we go through the gate,we go to the locker, we cut the locks off.\n\n")
    time.sleep(1)
    
    print(Fore.BLUE+"You look in, walk by.\n\nYou do not touch anything, you do not go inside the locker.\n\n")
    time.sleep(1)

    input(Fore. BLUE+"Terms of the auction are cash!!!\n\nEverybody ready???\n\n\t\tPress enter""")
    
    bidder_name = input(Fore.CYAN+"""\n\nAlongwith our veteran bidders Barry,Ursula, Roy, and Dave Hester, we have a new bidder amongst us.\n\n
What would you like us to call you new bidder???\n\n""")
    
    print(Fore.BLUE+f"\t\tWelcome {bidder_name}")
    input("\n\n\t\tPress enter to continue")
    

def round_1():
    
    # Begins the game with by asking the player to bid
    # If the player has the highest bid, moves to round_2
    
    global bidder_bid
    global proceed
    proceed = 'yes'
      
    print(Fore.BLUE+"\n\nThe auction starts with each bidder bidding.")
    
    #Allows user to reinput the bid incase of ValueError
    
    chances = 2
    while chances > 0:
        # error handling for incorrect input
        try:
            bidder_bid = int(input(Fore.CYAN+f"\n\nHow much do you want to bid {bidder_name}???\n"))
            break
        except ValueError:
            print("\t\tPlease input a number!")
            chances -= 1
    if chances == 0:
        disqualified()
        
    bid_list = []
    bid_list.append(bidder_bid)
    
    # Bid has to be in multiples of 10 only, given chances to correct this behvaiour
    # Disqualified if persisitent violation of rules
    
    if bidder_bid % 10 != 0:
        # error handling for incorrect input
        try:
            new_bidder_bid = int(input(Fore.BLUE+f"\n\nHey! {bidder_name}, you can bid only in multiples of 10,\
please bid again\n"))
        except ValueError:
            disqualified()
        bid_list.append(new_bidder_bid)
        if new_bidder_bid < bidder_bid or new_bidder_bid % 10 != 0:
            try:
                again_bidder_bid = int(input(Fore.YELLOW+"\n\nYour new bid should be higher than previous bid\
and should be a multiple of 10, please bid again\n"))
            except ValueError:
                disqualified()
            bid_list.append(again_bidder_bid)
            if again_bidder_bid <= new_bidder_bid or again_bidder_bid % 10 != 0:
                print(Fore.RED+"\n\nYou disobeyed the rules! You can\'t bid further!!!")
                disqualified()

    other_bidders = ['Barry', 'Ursula', 'Roy', 'Dave']
    other_bidders_bid = random.randint(10,300) * 10

    # Checks if the bidder wins the bid
    if max(bid_list) > other_bidders_bid:
        proceed = 'yes'
        time.sleep(2)
        proceed_1 = input(Fore.GREEN+f"\n\n\t\tWohoooo!!! {bidder_name}\n\n\
This amazing locker is all yours!!!\n\nAre you ready to see what's in store for you???\n\nEnter Yes or No ")
        
        if proceed_1.casefold() == proceed.casefold() :
            time.sleep(2.5)
            round_2()
        else:
            fail()
            
    elif max(bid_list) < other_bidders_bid:
        random_bidders = random.choice(other_bidders)
        print(Fore.RED+f"\n\nOops!!!! {bidder_name}, {random_bidders} outbid you.\n\n\
The bid was {other_bidders_bid}, that is higher than yours!\n\nSorry! try your luck at next auction.")
        fail()
    

    else:
        print(Fore.RED+"\n\nSomething went wrong!!!")
        fail()
    
def round_2():

    # In round 2 player gets to see the boxes in his locker
    # The boxes choosen by the player are evaluated. 
    # If the total value of the items in the boxes is more than the bid price player proceeds to round 3
    # else the game ends

    global profit_loss

    box_numbers = []

    while len(box_numbers) < 10: # while loop for getting random 10 distinct items
        item_number = random.randint(1,100)
        if item_number not in box_numbers:
            box_numbers.append(item_number)  
        else:
            continue

    print(Fore.MAGENTA+f"\n\nTake a look at your wonderful locker {bidder_name}!\n\n")
    time.sleep(1)
    print(Fore.MAGENTA+"You can choose 6 of the 10 items from the locker, the remaining 4 will go to auction house as their fee.\n\n")
    time.sleep(1)    
    print(Fore.MAGENTA+"\t\t\tCHOOSE WISELY!\n\nJust to mind you bigger isn't always better!!\n\n\n")
    time.sleep(1)
    print(Fore.MAGENTA+f"Your 10 boxes are numbered {box_numbers}")

    boxes_chosen_final = []

    # Player chooses his 6 boxes
    # Treatment of situation if same box is chosen more than once
    while len(boxes_chosen_final) < 6:
        # error handling for incorrect input
        try: 
            boxes_chosen = int(input(Fore.BLUE+f"\n\t\tChoose your box { len(boxes_chosen_final)+1 }\n"))
        except ValueError:
            print("\n\nYou were supposed to enter a numeric.")
            disqualified()
        
        if boxes_chosen in boxes_chosen_final:
            # error handling for incorrect input
            try: 
                box_replace = int(input (Fore.YELLOW+"\n\nYou have already choosen this box, please choose another box to continue"))
            except ValueError:
                print("\n\nYou were supposed to enter a numeric.")
                disqualified()

            if box_replace in boxes_chosen_final:
                disqualified()
            else:
                boxes_chosen_final.append(box_replace)
        else:
            boxes_chosen_final.append(boxes_chosen)

        # Treatment of situation if box chosen not in boxes available in locker
        if boxes_chosen_final[-1] not in box_numbers:
            del boxes_chosen_final[-1]
            print(Fore.YELLOW+"\n\nYou chose a box that isn't available in your locker.\n\n\t\t Choose again.")

            try:
                boxes_chosen2 = int(input(Fore.BLUE+"\n\t\tChoose your box\n"))
            except ValueError:
                print("\n\nYou were supposed to enter a numeric.")
                disqualified()
            if boxes_chosen2 in boxes_chosen_final or boxes_chosen2 not in box_numbers:
                disqualified()
            else:
                boxes_chosen_final.insert(-1, boxes_chosen2)

        else:
            continue

    # Player gets to know payoff corresponding to every box he has chosen 
    time.sleep(1)   
    
    print(Fore.MAGENTA+"\nYay! you are step closer to knowing your payoffs!")
    time.sleep(1)
    
    print(Fore.GREEN+"\n\n\n\n\t\t\tBrace up $$$$$")
    time.sleep(1)
    
    input(Fore.MAGENTA+"\n\n\n\n\nPress enter to know your payoff")


    random_payoff = { key : random.randint(-50,1000) for key in range(100) }
    payoff = {}

    for value in boxes_chosen_final:
        payoff[value] = random_payoff.get(value, 0)
    payoff_keys = list(payoff.keys())
    for k in payoff_keys[:5]:
        time.sleep(1.5)   
        print("\n\n\nFor box number", k, "you earned", payoff[k])

    final_payoff = sum(payoff.values())
    profit_loss = final_payoff - bidder_bid # total profit (or loss) from the locker
    time.sleep(1.5)

    # Player finds an antique, gets it checked out by collector
    print(Fore.CYAN+f"\n\n\n{bidder_name}: Wait!!! what is in this box numbered {payoff_keys[5]}\n\n")
    
    print(emoji.emojize(":thinking_face:")*20)
    time.sleep(3)
    
    print(Fore.CYAN+"\n\nI have never seen anything like this.\n\nIt is a long table with wheel in center.\n\n\
Looks like some numbers embossed on a velvetty cloth.\n\nTheres is a little white ball also.\n\n")
    time.sleep(3)
    
    print(Fore.GREEN+"Looks like something to 'gamble on'.\n\nMay be I have found a true Treasure!!\n\nWhat are the odds huhhh!!!\n\n")
    time.sleep(2)
    
    print(Fore.CYAN+"I definitely need to get it checked by a collector.")
    time.sleep(1)
    
    print(Fore.MAGENTA+f"\n\n\n{bidder_name} GOING TO MEET A COLLECTOR!\n\n")

    for i in range(10):
        time.sleep(0.5)
        print(emoji.emojize(":man_running:"))


    print(Fore.CYAN+f"""\n\n
{bidder_name}: Hey! Collector, I am {bidder_name}!, I found this in a storage unit and thought I should definitely get it checked.\n\nWhat do you think of it?\n\n\n\n""")

    time.sleep(3)

    for i in range (5):
        time.sleep(0.5)
        print(emoji.emojize(":thinking_face:"))
    time.sleep(1.5)

    # Collector's evaluation of the antique
    # Determination of final payoff to decide if player qualifies for round_3

    if payoff[payoff_keys[-1]] < 250:
        # The antique item is not valuable
        print(Fore.BLACK+f"""\n\n
Collector:Well, what you have got is a Monte carlo roulette table.\n\nIt is rare to find one outside of Monte Carlo in France.\n\n
Look it was made in early 1800's but...\n\n...it looks pretty worn out.\n\n""")
        
        input(Fore.CYAN+"Ready to know how much this is worth??\n\n\t\tPress enter to continue\n\n")
        
        print(Fore.RED+f"""
Collector:Sorry! it could only get you {payoff[payoff_keys[-1]]} dollars.\n\n """)
        
        input(Fore.CYAN+"Press enter to continue\n\n")

        if profit_loss < 0:
            # player failed to collect profit from items
            print(Fore.RED+f"{bidder_name}, your day seems to be turning out really bad!!\n\n\
Your locker seemed a disaster.\n\nYou lost money.\n\n")
            time.sleep(2)
            
            print(Fore.RED+f"You had bid {bidder_bid}, but got only", final_payoff,".\n\n\
Your total loss is",abs(profit_loss)," dollars.\n\nBetter luck next time.\n\n")
            fail() 

        elif profit_loss > 0:
            # qualifies player for round 3
            print(Fore.GREEN+f"\n\nWohooooooo!!!! {bidder_name}, alongwith the collectible, your locker turned out to be worth",final_payoff,"\n\n\
You got yourself a profit of", profit_loss," dollars.\n\nCONGRATULATIONS!!!!\n\n")
            input(Fore.MAGENTA+"\t\t\tPress enter to continue\n\n")


            print(Fore.GREEN+f"""
Collector:Cheer up {bidder_name} even if the collectible wasn't that valuable we still had fun talking...\n\n""")
            time.sleep(1)
            
            print(Fore.GREEN+f"Collector:If you want to continue the fun and want to earn more you can join me at my casino in Vegas and try your luck.\n\n")
            time.sleep(2)
            
            proceed_2 = input(Fore.CYAN+f" What say {bidder_name}, ready to hop on a party bus to VEGASSSSS!!!\n\n\n\t\tEnter Yes or No\n\n")
            
            if proceed_2.casefold() == proceed.casefold() :
                round_3()
            else:
                fail()
        else:
            fail()

    elif payoff[payoff_keys[-1]] >= 250:
        # case when antique is valuable
        print(Fore.BLACK+f"""\n\n
Collector:What you have got is a Monte carlo roulette table.\n\nIt is rare to find one outside of Monte Carlo France.\n\n""")
        time.sleep(1.5)

        print(Fore.BLACK+"Look it was made in early 1800's, yet it looks pretty well kept, seems like you found something antique.\n\n") 
        
        input(Fore.CYAN+"Ready to know how much is it worth???\n\n\t\t\tPress enter to continue.")

        input(Fore.GREEN+f"Well!!! {bidder_name} You just earned yourself {payoff[payoff_keys[-1]]} .\n\nCONGRATULATIONS!!!\n\n\t\t\tPress enter to continue.")

        if profit_loss < 0:
            # player failed to collect profit from items
            print(Fore.RED+f"\n\n{bidder_name} well, the collectible may have fetch you some money but overall it turned out to be a bad day!\n\n\
Your locker seemed a disaster.\n\nYou lost money.\n\n")
            time.sleep(2)

            print(Fore.RED+f"You had bid {bidder_bid}, but got only {final_payoff}.\n\n\
Yor total loss is",abs(profit_loss),"dollars.\n\nBetter luck next time.\n\n")
            fail()

        elif profit_loss > 0:
            # qualifies player for round 3
            print(Fore.GREEN+f"""\n\nWohooooooo!!!! {bidder_name}, alongwith the collectible, your locker turned out to be worth {final_payoff}\n\n\
You got yourself a profit of {profit_loss} dollars.\n\nCONGRATULATIONS!!!!\n\n""")
            
            input(Fore.MAGENTA+"Press enter to continue")

            print(Fore.GREEN+f"""
Collector: Hey! {bidder_name} It was real fun looking at your unique roulette table and talkin to you...\n\n""")
            time.sleep(2)
            
            print(Fore.GREEN+f"Collector:If you want to continue the fun and want to earn more you can join me at my casino in Vegas and try your luck.")
            time.sleep(2)
            
            proceed_3=input(Fore.CYAN+f" What say {bidder_name}, ready to hop on a party bus to VEGASSSSS!!!\n\n\n Enter Yes or No\n\n")
            
            if proceed_3.casefold() == proceed.casefold() :
                round_3()
            else:
                fail()
    else:
        fail()

def round_3():
    
    # Player is off to Vegas to bet on roulette
    # Player can choose from 5 different scenarios each with multiple options to bet on
    # Player gets reward corresponding to the option he has chosen
    
    global casino_payoff
    global bid_casino
    
    time.sleep(3)
    
    input(Fore.MAGENTA+f"\n\nWohoooooo!!!!!! {bidder_name}\n\nYou are at VENETIAN, the best casino, in VEGAS!!!!\n\n\
Ready to roll!!\n\nPress enter to continue")
    print(Fore.BLUE+"You are at a roulette table!!!\n\nReady to put your bet!!!")
    time.sleep(1)
    
    try:
        bid_casino = int(input(Fore.CYAN+"\n\nEnter how many dollars you want to bet\n\n\t\t"))
    except ValueError:
        print("\n\nYou were supposed to enter a numeric.")
        disqualified()
        
    random_casino = random.randint(1,36)
    
    # Modified roulette to give player 5 scenarios to choose from
    
    try:
        choice_casino = int(input(Fore.BLUE+"\nChoose from 1, 2, 3, 4, 5, based on the description below to continue\n1.Enter 1 if you want to bet on a 'specific' number between  1-36\n2.Enter 2 if you want to bet on 'range' 1-12.\n3.Enter 3 if you want to bet on 'range' 13-24\n4.Enter 4 if you want to bet on 'range' between 25-36.\n5.Enter 5 if you want to get the option to bet on 'odd' or 'even' number\n\n\t\t"))
    except ValueError:
        print("\n\nYou were supposed to enter a numeric.")
        disqualified()
    
    if choice_casino == 1:
        try:
            guess_casino = int(input(Fore.CYAN+"\n\nEnter the number you want to bid on\n\n"))
        except ValueError:
            print("\n\nYou were supposed to enter a numeric.")
            disqualified()
        
        if guess_casino == random_casino:
            print(Fore.GREEN+"\n\t\tCONGRATULATIONS!!!\n\nYou win!!!!\n\nYour money becomes 9 times and u get\n\n\t\t", bid_casino*9)
            time.sleep(3)
            casino_payoff = bid_casino * 9
            end_message()
            
            
        elif guess_casino != random_casino:
            print(Fore.RED+"\n\t\tSORRY!!!\n\nYou lose, the number on roulette was", random_casino)
            conditional_win()
        else:
            print(Fore.RED+"Something went wrong")
    
    elif choice_casino == 5:
        odd_even = input(Fore.CYAN+"\n\nChoose either 'odd' or 'even'\n\n\t")
        if random_casino % 2 == 0 and odd_even == 'even' or random_casino % 2 != 0 and odd_even == 'odd':
            print(fore.GREEN+"\n\nWohoooo!!, the number on roulette was ", random_casino, "your money doubles\n\nYou get",bid_casino*2,"!!!")
            casino_payoff = bid_casino*2
            time.sleep(3)
            end_message()
        else: 
            print(Fore.RED+"\nSORRY!!!\n\nYou lose, the number on roulette was", random_casino)
            conditional_win()
    elif choice_casino == 2 or choice_casino == 3  or choice_casino == 4:
        if choice_casino == 2 and random_casino in range(1,12) or choice_casino == 3 and random_casino in range(13,24) or choice_casino == 4 and random_casino in range(25,36):
            print(Fore.GREEN+"\nWohoooo!!!, the number on roulette was", random_casino,".\nCONGRATULATIONS!!!!\nYour money triples, you get", bid_casino * 3)
            casino_payoff = bid_casino*3
            time.sleep(3)
            end_message()
            
        else:
            print(Fore.RED+"\nSORRY!!!\n\n you lose!, the number on roulette was", random_casino,".\n")
            conditional_win()
    else:
        print(Fore.RED+"Something went wrong")
        fail()
        

game_start()
